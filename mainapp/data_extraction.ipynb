# %%
import git
import os

# Specify the path of the file to be deleted
file_path = 'D:/Learning/Projects/PhonepePulseDataVisualization/src/phonepeData'

# Check if the file exists before attempting to delete it
if not os.path.exists(file_path):
    repo = git.Repo.clone_from('https://github.com/PhonePe/pulse.git','D:/Learning/Projects/PhonepePulseDataVisualization/src/phonepeData')

# %%
def format_number(number):
    number = int(number)
    if number >= 10000000:  # If number is greater than or equal to 10 crores
        return "{:,.2f} crores".format(number / 10000000)
    elif number >= 100000:  # If number is greater than or equal to 1 lakh
        return "{:,.2f} lakhs".format(number / 100000)
    elif number >= 1000:  # If number is greater than or equal to 1 thousand
        return "{:,.2f} thousands".format(number / 1000)
    else:
        return "{:,.2f}".format(number)

# %%
import json
import pandas as pd
aggreated_transaction_path = 'D:/Learning/Projects/PhonepePulseDataVisualization/src/phonepeData/data/aggregated/transaction/country/india/'

transaction ={'Year':[],'Quarter':[],'Transaction_type':[], 'Transaction_count':[], 'Transaction_amount':[]}

year_list = os.listdir(aggreated_transaction_path)

for year in year_list:
    if year  == 'state':
        continue
    path = aggreated_transaction_path+year+'/'
    quarter_list = os.listdir(path)
    for quarter in quarter_list:
        qtr_path = path+quarter
        D = open(qtr_path,'r')
        data =json.load(D)
        for value in  data['data']['transactionData']:
            Name = value['name']
            count = value['paymentInstruments'][0]['count']
            amount=format_number(value['paymentInstruments'][0]['amount'])
            transaction['Transaction_amount'].append(amount)
            transaction['Transaction_count'].append(count)
            transaction['Transaction_type'].append(Name)
            transaction['Year'].append(year)
            transaction['Quarter'].append(int(quarter.strip('.json')))

transcation_df = pd.DataFrame(transaction)

# %%
transcation_df

# %%
import json
import pandas as pd
import os
aggreated_user_state_path='D:/Learning/Projects/PhonepePulseDataVisualization/src/phonepeData/data/aggregated/transaction/country/india/state/'

state_transcation ={'State':[],'Year':[],'Quarter':[],'Transaction_type':[], 'Transaction_count':[], 'Transaction_amount':[]}
state_list = os.listdir(aggreated_user_state_path)
for state in state_list:  
    year_path = aggreated_user_state_path+state+'/'
    year_list = os.listdir(year_path)
    for year in year_list:
        path = year_path+year+'/'
        quarter_list = os.listdir(path)
        for quarter in quarter_list:
            qtr_path = path+quarter
            D = open(qtr_path,'r')
            data =json.load(D)
            for value in  data['data']['transactionData']:
                Name = value['name']
                count = value['paymentInstruments'][0]['count']
                amount=format_number(value['paymentInstruments'][0]['amount'])
                state_transcation['Transaction_amount'].append(amount)
                state_transcation['Transaction_count'].append(count)
                state_transcation['Transaction_type'].append(Name)
                state_transcation['Year'].append(year)
                state_transcation['State'].append(state)
                state_transcation['Quarter'].append(int(quarter.strip('.json')))

st_transcation_df = pd.DataFrame(state_transcation)         
st_transcation_df['State'] = st_transcation_df['State'].str.title()

# %%
states_list = st_transcation_df["State"].unique().tolist()
states_list
# Out:
# ['Andaman-&-Nicobar-Islands',
#  'Andhra-Pradesh',
#  'Arunachal-Pradesh',
#  'Assam',
#  'Bihar',
#  'Chandigarh',
#  'Chhattisgarh',
#  'Dadra-&-Nagar-Haveli-&-Daman-&-Diu',
#  'Delhi',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal-Pradesh',
#  'Jammu-&-Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Ladakh',
#  'Lakshadweep',
#  'Madhya-Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Puducherry',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil-Nadu',
#  'Telangana',
#  'Tripura',
#  'Uttar-Pradesh',
#  'Uttarakhand',
#  'West-Bengal']

# %%
import json
import pandas as pd
import os
aggreated_user_state_path='D:/Learning/Projects/PhonepePulseDataVisualization/src/phonepeData/data/aggregated/user/country/india/state/'

state_user ={'State': [], 'Year': [], 'Quarter': [], 'Brands': [], 'Count': [],
            'Percentage': [],'Users_count':[],'App_opening':[]}
state_list = os.listdir(aggreated_user_state_path)
for state in state_list:  
    year_path = aggreated_user_state_path+state+'/'
    year_list = os.listdir(year_path)
    for year in year_list:
        path = year_path+year+'/'
        quarter_list = os.listdir(path)
        for quarter in quarter_list:
            qtr_path = path+quarter
            D = open(qtr_path,'r')
            data =json.load(D)
            print(data['data']['aggregated']['registeredUsers'])
            user_count = data['data']['aggregated']['registeredUsers']
            app_open = data['data']['aggregated']['appOpens']
            try:  
                for value in  data['data']['usersByDevice']:
                    Brand = value['brand']
                    count = value['count']
                    percent = value['percentage']
                    state_user['Brands'].append(Brand)
                    state_user['Count'].append(count)
                    state_user['Percentage'].append(percent)
                    state_user['Year'].append(year)
                    state_user['State'].append(state)
                    state_user['Quarter'].append(int(quarter.strip('.json')))
                    state_user['Users_count'].append(user_count)
                    state_user['App_opening'].append(app_open)
            except:
                pass        

            

st_user_df = pd.DataFrame(state_user)
# Out:
# 6740
# 9405
# 12149
# 15222
# 18596
# 21731
# 23931
# 25960
# 28368
# 32710
# 41335
# 52396
# 57758
# 62095
# 66982
# 71780
# 76288
# 80530
# 84642
# 88442
# 92484
# 96329
# 100255
# 103978
# 3336450
# 4402540
# 5427617
# 6857409
# 8283019
# 9389003
# 10458693
# 11757883
# 13022060
# 14319675
# 15692405
# 17076565
# 18363733
# 19620905
# 21059898
# 22489029
# 23857951
# 25157264
# 26496330
# 27778016
# 29065863
# 30240061
# 31493897
# 32658698
# 21495
# 32883
# 45922
# 61852
# 76957
# 95885
# 112149
# 129321
# 149066
# 177534
# 206046
# 231292
# 251240
# 270572
# 293073
# 314944
# 335339
# 354528
# 373372
# 390307
# 408273
# 426410
# 444789
# 462088
# 385237
# 571046
# 784802
# 1039221
# 1259085
# 1500128
# 1731523
# 1941220
# 2185938
# 2550883
# 2830011
# 3106153
# 3358448
# 3617056
# 3918480
# 4209591
# 4492589
# 4755787
# 5016910
# 5247776
# 5499650
# 5749682
# 5998586
# 6234780
# 2133804
# 3005872
# 3784535
# 4776665
# 5745117
# 6589759
# 7380265
# 8342274
# 9351234
# 10603767
# 11763213
# 12889833
# 13946288
# 14972134
# 16160771
# 17335981
# 18484658
# 19569894
# 20694376
# 21738117
# 22796011
# 23781971
# 24776510
# 25695856
# 86268
# 115219
# 143893
# 177747
# 209175
# 240439
# 267337
# 289590
# 312887
# 336351
# 362588
# 391402
# 419998
# 448572
# 480463
# 512092
# 541549
# 569582
# 598698
# 627563
# 654522
# 678662
# 704144
# 727594
# 679263
# 950675
# 1217792
# 1579998
# 1908898
# 2191066
# 2435058
# 2725900
# 3016487
# 3401658
# 3799386
# 4190601
# 4514551
# 4837055
# 5206084
# 5565481
# 5916961
# 6238349
# 6562237
# 6846822
# 7159660
# 7469508
# 7779977
# 8057016
# 53258
# 71458
# 92107
# 116511
# 140532
# 158580
# 176929
# 197598
# 218496
# 244814
# 267946
# 296493
# 321396
# 344994
# 371874
# 398963
# 424570
# 449016
# 474807
# 500125
# 524617
# 546364
# 569035
# 590760
# 2087022
# 2756141
# 3504911
# 4630313
# 5499263
# 6165448
# 6782286
# 7289883
# 7826197
# 8391139
# 9044174
# 9747968
# 10467210
# 11182699
# 11980061
# 12785127
# 13539197
# 14260143
# 15009523
# 15764149
# 16480011
# 17103089
# 17747167
# 18363626
# 91936
# 122174
# 153802
# 195350
# 238152
# 278940
# 317194
# 353546
# 391900
# 430639
# 474962
# 527584
# 570035
# 609106
# 653458
# 697178
# 738628
# 777779
# 817830
# 855202
# 892185
# 926020
# 961831
# 995923
# 2690048
# 3565825
# 4433183
# 5579040
# 6652536
# 7574645
# 8429299
# 9323799
# 10259843
# 11392657
# 12467847
# 13605203
# 14670126
# 15735981
# 16946761
# 18139201
# 19265314
# 20321596
# 21394721
# 22412353
# 23436230
# 24396768
# 25383429
# 26312655
# 1847357
# 2447221
# 3020398
# 3793079
# 4538767
# 5178030
# 5783752
# 6366679
# 7018770
# 7682878
# 8398816
# 9129873
# 9827905
# 10530594
# 11325336
# 12116439
# 12866988
# 13576065
# 14303933
# 14994944
# 15688161
# 16314236
# 16956489
# 17556642
# 227373
# 315299
# 407634
# 526343
# 653205
# 772603
# 876184
# 985945
# 1106025
# 1249867
# 1378634
# 1508766
# 1622951
# 1743151
# 1880626
# 2013747
# 2143483
# 2264407
# 2381576
# 2483076
# 2594668
# 2706470
# 2816046
# 2924952
# 176425
# 261609
# 342529
# 436563
# 530669
# 631193
# 658455
# 673367
# 735408
# 845294
# 949819
# 1079022
# 1174818
# 1261267
# 1359860
# 1456810
# 1549320
# 1635570
# 1719185
# 1793434
# 1873039
# 1953132
# 2031447
# 2108166
# 885762
# 1230599
# 1532362
# 1913949
# 2279329
# 2604854
# 2915511
# 3281371
# 3651393
# 4061035
# 4480027
# 4917938
# 5313049
# 5701503
# 6151843
# 6596196
# 7025275
# 7426174
# 7836429
# 8217638
# 8609107
# 8980709
# 9360730
# 9707336
# 3717763
# 5030665
# 6372649
# 8315802
# 10266174
# 11968087
# 13635075
# 15385416
# 17016980
# 18655366
# 20487550
# 22400182
# 24095832
# 25751023
# 27614221
# 29459646
# 31200349
# 32831447
# 34493994
# 36081698
# 37681426
# 39122314
# 40634390
# 42031396
# 784184
# 1066587
# 1347598
# 1757326
# 2136624
# 2550167
# 2990963
# 3503938
# 4078316
# 4728844
# 5582300
# 6387169
# 6936943
# 7416083
# 7949425
# 8473810
# 8972299
# 9442533
# 9933977
# 10382102
# 10822723
# 11237341
# 11669143
# 12084974
# 8784
# 12918
# 17749
# 23883
# 29649
# 35516
# 39173
# 43108
# 47790
# 53034
# 58401
# 64853
# 69919
# 75048
# 81210
# 87057
# 92492
# 97517
# 102299
# 106337
# 110991
# 115736
# 120435
# 124828
# 501
# 686
# 918
# 1156
# 1416
# 1747
# 2117
# 2427
# 2772
# 3187
# 3644
# 4179
# 4577
# 4896
# 5287
# 5638
# 5990
# 6327
# 6645
# 6961
# 7267
# 7585
# 7912
# 8225
# 2553603
# 3441662
# 4309309
# 5365442
# 6414403
# 7301172
# 8180664
# 9165241
# 10151371
# 11374423
# 12564224
# 13737947
# 14839427
# 15940935
# 17210233
# 18456243
# 19656147
# 20766417
# 21884220
# 22913924
# 24002818
# 25042930
# 26109033
# 27078072
# 6106994
# 8222371
# 10435033
# 13381602
# 16284451
# 18776975
# 21313081
# 23745297
# 26168390
# 28765086
# 31409513
# 34432631
# 37077537
# 39664697
# 42581217
# 45482506
# 48227630
# 50802786
# 53432602
# 55954028
# 58470784
# 60766850
# 63150997
# 65422120
# 29925
# 46055
# 61935
# 82589
# 99527
# 117747
# 136316
# 155358
# 177374
# 215496
# 258563
# 288772
# 312668
# 335409
# 361749
# 387746
# 411900
# 434563
# 457063
# 477292
# 498337
# 519799
# 541572
# 564130
# 18513
# 26618
# 37281
# 49634
# 61487
# 74746
# 87395
# 100030
# 113814
# 136211
# 157741
# 176447
# 190869
# 205686
# 223065
# 240268
# 255839
# 269943
# 283487
# 295322
# 308324
# 322382
# 336282
# 349330
# 7593
# 10422
# 14502
# 19365
# 23670
# 28696
# 34134
# 39809
# 46499
# 55574
# 68315
# 78731
# 85750
# 92552
# 100647
# 108405
# 115295
# 121535
# 127735
# 132870
# 138751
# 145061
# 151378
# 157627
# 15074
# 22436
# 32090
# 42997
# 53911
# 66891
# 80077
# 93124
# 107143
# 130205
# 173106
# 192188
# 207808
# 223337
# 241797
# 259990
# 276483
# 292104
# 307386
# 321205
# 335936
# 351024
# 366203
# 381162
# 1594015
# 2185781
# 2795718
# 3623911
# 4320744
# 4845359
# 5387209
# 6115537
# 6652970
# 7258315
# 7901755
# 8598751
# 9233009
# 9891029
# 10652490
# 11399235
# 12124779
# 12801990
# 13493282
# 14127239
# 14787083
# 15420061
# 16064459
# 16680992
# 49318
# 65580
# 81546
# 109494
# 133059
# 156458
# 177868
# 204292
# 230908
# 255600
# 285173
# 319626
# 346279
# 369961
# 396609
# 423167
# 448051
# 471663
# 496570
# 520649
# 543819
# 564431
# 586550
# 607838
# 847142
# 1152190
# 1473148
# 1865715
# 2226590
# 2600112
# 2962713
# 3321742
# 3739502
# 4225481
# 4694233
# 5157868
# 5568777
# 5976548
# 6434862
# 6880103
# 7302726
# 7702100
# 8097582
# 8462753
# 8837408
# 9197055
# 9555997
# 9898002
# 3158202
# 4212964
# 5175453
# 6358738
# 7712204
# 8783935
# 9797304
# 10925031
# 12142053
# 13563201
# 14969412
# 16329494
# 17661088
# 18980985
# 20499465
# 21977202
# 23398857
# 24716181
# 26042948
# 27255927
# 28523031
# 29745609
# 30997182
# 32157348
# 20051
# 28097
# 37637
# 48538
# 58956
# 70999
# 82128
# 92972
# 104631
# 119921
# 134773
# 148543
# 160213
# 171740
# 184693
# 197407
# 209616
# 220994
# 232025
# 241968
# 252440
# 262728
# 272829
# 282575
# 2104754
# 2996036
# 3900177
# 5199878
# 6296303
# 7429609
# 8428835
# 9620493
# 10872368
# 12150786
# 13643451
# 15357586
# 16632608
# 17804542
# 19127440
# 20433142
# 21667020
# 22829720
# 24019964
# 25136112
# 26270663
# 27317599
# 28405436
# 29452801
# 3315560
# 4260115
# 5138501
# 6529679
# 7963425
# 9046007
# 10090557
# 11220691
# 12306860
# 13378191
# 14590882
# 15927797
# 17149069
# 18306880
# 19615278
# 20917649
# 22150612
# 23314363
# 24506111
# 25656381
# 26804259
# 27814633
# 28896668
# 29902636
# 55157
# 83369
# 116874
# 153265
# 183254
# 217644
# 245456
# 272298
# 299962
# 336666
# 376731
# 409110
# 439636
# 472153
# 509929
# 546292
# 582124
# 615782
# 649143
# 678741
# 710884
# 743024
# 774678
# 806344
# 4694250
# 6442554
# 8096483
# 10341964
# 12458661
# 14316349
# 16044607
# 17949542
# 20136256
# 22498519
# 24838116
# 27249134
# 29482075
# 31651894
# 34151882
# 36617655
# 38999692
# 41247289
# 43537920
# 45648650
# 47806049
# 49829833
# 51870932
# 53799813
# 483043
# 649142
# 810612
# 1012103
# 1224955
# 1414339
# 1585859
# 1752677
# 1943606
# 2148567
# 2365438
# 2596244
# 2802122
# 3004040
# 3233509
# 3460015
# 3674829
# 3877056
# 4081976
# 4272049
# 4464369
# 4645322
# 4829992
# 5001826
# 2604789
# 3833795
# 4851740
# 6279278
# 7449425
# 8612795
# 9643222
# 10885058
# 11960822
# 13222022
# 14448366
# 15662093
# 16808799
# 17979979
# 19323278
# 20644527
# 21919787
# 23124388
# 24372048
# 25536381
# 26732895
# 27827662
# 28966414
# 30064546

# %%
st_user_df
# Out:
#                           State  Year  Quarter   Brands    Count  Percentage  \
# 0     andaman-&-nicobar-islands  2018        1   Xiaomi     1665    0.247033
# 1     andaman-&-nicobar-islands  2018        1  Samsung     1445    0.214392
# 2     andaman-&-nicobar-islands  2018        1     Vivo      982    0.145697
# 3     andaman-&-nicobar-islands  2018        1     Oppo      501    0.074332
# 4     andaman-&-nicobar-islands  2018        1  OnePlus      332    0.049258
# ...                         ...   ...      ...      ...      ...         ...
# 6727                west-bengal  2022        1   Lenovo   330017    0.015056
# 6728                west-bengal  2022        1  Infinix   284678    0.012987
# 6729                west-bengal  2022        1     Asus   280347    0.012790
# 6730                west-bengal  2022        1    Apple   277752    0.012671
# 6731                west-bengal  2022        1   Others  2196334    0.100199
#
#       Users_count  App_opening
# 0            6740            0
# 1            6740            0
# 2            6740            0
# 3            6740            0
# 4            6740            0
# ...           ...          ...
# 6727     21919787    236131065
# 6728     21919787    236131065
# 6729     21919787    236131065
# 6730     21919787    236131065
# 6731     21919787    236131065
#
# [6732 rows x 8 columns]

# %%
import json
import pandas as pd
aggreated_user_path='D:/Learning/Projects/PhonepePulseDataVisualization/src/phonepeData/data/aggregated/user/country/india/'

user ={'Year': [], 'Quarter': [], 'Brands': [], 'Count': [],
            'Percentage': []}

year_list = os.listdir(aggreated_user_path)
for year in year_list:
    if year == 'state':
        continue
    path = year_path+year+'/'
    quarter_list = os.listdir(path)
    for quarter in quarter_list:
        qtr_path = path+quarter
        D = open(qtr_path,'r')
        data =json.load(D)
        try:
            for value in  data['data']['usersByDevice']:
                Brand = value['brand']
                count = value['count']
                percent = value['percentage']
                user['Brands'].append(Brand)
                user['Count'].append(count)
                user['Percentage'].append(percent)
                user['Year'].append(year)
                user['Quarter'].append(int(quarter.strip('.json')))
        except:
            pass        

user_df = pd.DataFrame(user)

# %%
user_df

# %%
import json
import pandas as pd
map_transaction_path = 'D:/Learning/Projects/PhonepePulseDataVisualization/src/phonepeData/data/map/transaction/hover/country/india/'

map_transaction ={'Year':[],'Quarter':[],'State':[], 'Transaction_count':[], 'Transaction_amount':[]}

year_list = os.listdir(map_transaction_path)

for year in year_list:
    if year  == 'state':
        continue
    path = map_transaction_path+year+'/'
    quarter_list = os.listdir(path)
    for quarter in quarter_list:
        qtr_path = path+quarter
        D = open(qtr_path,'r')
        data =json.load(D)
        for value in  data['data']['hoverDataList']:
            Name = value['name']
            count = value['metric'][0]['count']
            amount=format_number(value['metric'][0]['amount'])
            map_transaction['Transaction_amount'].append(amount)
            map_transaction['Transaction_count'].append(count)
            map_transaction['State'].append(Name)
            map_transaction['Year'].append(year)
            map_transaction['Quarter'].append(int(quarter.strip('.json')))

map_transcation_df = pd.DataFrame(map_transaction)

# %%
map_transcation_df

# %%
import json
import pandas as pd
map_state_transaction_path = 'D:/Learning/Projects/PhonepePulseDataVisualization/src/phonepeData/data/map/transaction/hover/country/india/state/'

map_st_transaction ={'Year':[],'Quarter':[],'State':[],'District':[],'Transaction_count':[], 'Transaction_amount':[]}

state_list = os.listdir(map_state_transaction_path)

for state in state_list:
    state_path = map_state_transaction_path+state+'/'
    year_list = os.listdir(state_path)
    for year in year_list:
        path = state_path+year+'/'
        quarter_list = os.listdir(path)
        for quarter in quarter_list:
            qtr_path = path+quarter
            D = open(qtr_path,'r')
            data =json.load(D)
            try:
                for value in  data['data']['hoverDataList']:
                    Name = value['name']
                    count = value['metric'][0]['count']
                    amount=format_number(value['metric'][0]['amount'])
                    map_st_transaction['Transaction_amount'].append(amount)
                    map_st_transaction['Transaction_count'].append(count)
                    map_st_transaction['District'].append(Name)
                    map_st_transaction['State'].append(state)
                    map_st_transaction['Year'].append(year)
                    map_st_transaction['Quarter'].append(int(quarter.strip('.json')))
            except:
                pass        

map_st_transcation_df = pd.DataFrame(map_st_transaction)

# %%
map_st_transcation_df

# %%
import json
import pandas as pd
map_user_path='D:/Learning/Projects/PhonepePulseDataVisualization/src/phonepeData/data/map/user/hover/country/india/'

mp_user ={'Year': [], 'Quarter': [], 'State': [], 'Count': []}

year_list = os.listdir(map_user_path)
for year in year_list:
    if year == 'state':
        continue
    path = map_user_path+year+'/'
    quarter_list = os.listdir(path)
    for quarter in quarter_list:
        qtr_path = path+quarter
        D = open(qtr_path,'r')
        data =json.load(D)
        # try:
         # Extract state names and data
        states = list(data['data']['hoverData'].keys())
        for value in  states:
            state = value
            count = data['data']['hoverData'][state]["registeredUsers"]
            mp_user['State'].append(state)
            mp_user['Count'].append(count)
            mp_user['Year'].append(year)
            mp_user['Quarter'].append(int(quarter.strip('.json')))
        # except Exception as e:
            # print(e)
            # pass        

map_user_df = pd.DataFrame(mp_user)

# %%
map_user_df

# %%
import json
import pandas as pd
import os

map_st_user_path = "D:/Learning/Projects/PhonepePulseDataVisualization/src/phonepeData/data/map/user/hover/country/india/state/"

mp_st_user = {
    "Year": [],
    "Quarter": [],
    "State": [],
    "District": [],
    "Count": [],
    "App_Opening": [],
}
mp_state_list = os.listdir(map_st_user_path)
for state in mp_state_list:
    year_path = map_st_user_path + state + "/"
    year_list = os.listdir(year_path)
    for year in year_list:
        path = year_path + year + "/"
        quarter_list = os.listdir(path)
        for quarter in quarter_list:
            qtr_path = path + quarter
            D = open(qtr_path, "r")
            data = json.load(D)
            # try:
            # Extract state names and data
            districts = list(data["data"]["hoverData"].keys())
            for value in districts:
                district = value
                count = data["data"]["hoverData"][district]["registeredUsers"]
                app_opening = data["data"]["hoverData"][district]["appOpens"]
                mp_st_user["State"].append(state)
                mp_st_user["Count"].append(count)
                mp_st_user["App_Opening"].append(app_opening)
                mp_st_user["Year"].append(year)
                mp_st_user["Quarter"].append(int(quarter.strip(".json")))
                mp_st_user["District"].append(district)
            # except Exception as e:
            # print(e)
            # pass
    map_st_user_df = pd.DataFrame(mp_st_user)
    map_st_user_df["State"] = map_st_user_df["State"].str.title()

# %%
map_st_user_df.
# Out:
#    Year  Quarter                      State  \
# 0  2018        1  Andaman-&-Nicobar-Islands
# 1  2018        1  Andaman-&-Nicobar-Islands
# 2  2018        1  Andaman-&-Nicobar-Islands
# 3  2018        2  Andaman-&-Nicobar-Islands
# 4  2018        2  Andaman-&-Nicobar-Islands
#
#                             District  Count  App_Opening
# 0  north and middle andaman district    632            0
# 1             south andaman district   5846            0
# 2                  nicobars district    262            0
# 3  north and middle andaman district    911            0
# 4             south andaman district   8143            0

# %%
import psycopg2

def psql_client():
    try:
        connection = psycopg2.connect(host='localhost',
                user='postgres',
                password='admin',
                database='phonepe')
        return connection
    except Exception as e:
        print(e)

# %%
import uuid
import psycopg2

try:
    agg_user = map_st_user_df
    connection = psql_client()
    cursor = connection.cursor()

    for index, row in agg_user.iterrows():
        # Get state_id
        state_name = row["State"]
        cursor.execute(f"SELECT id FROM phonepe.state WHERE state_name='{state_name}'")
        state_id = cursor.fetchone()[0]
        cursor.fetchall()
        # Get year_id
        year_value = row["Year"]
        cursor.execute(f"SELECT id FROM phonepe.year WHERE year={year_value}")
        year_id = cursor.fetchone()[0]
        cursor.fetchall()  # Fetch all results to clear the unread result
        # Insert transaction data
        cursor.execute(
            f"""INSERT INTO phonepe.users_location(user_location_key,
                               district_name,
                               users_count,
                               app_openig,
                               quarter,
                               state_key,
                               year_key)
	                            VALUES ('{uuid.uuid4()}','{row['District']}',{row['Count']},{row['App_Opening']},{row['Quarter']},{state_id},{year_id});"""
        )
        connection.commit()
except (psycopg2.Error, Exception) as e:
    print.write("An error occurred:", e)
finally:
    if connection:
        connection.close()

# %%
import json
import pandas as pd
import os
top_transcn_path='D:/Learning/Projects/PhonepePulseDataVisualization/src/phonepeData/data/top/transaction/country/india/'

top_transcn_by_st = {'State': [], 'Year': [], 'Quarter': [], 'Transaction_count': [],
            'Transaction_amount': []}
top_transcn_by_dt = {'District': [], 'Year': [], 'Quarter': [], 'Transaction_count': [],
            'Transaction_amount': []}
top_transcn_by_pcd = {'PinCode': [], 'Year': [], 'Quarter': [], 'Transaction_count': [],
            'Transaction_amount': []}

year_list = os.listdir(top_transcn_path)

for year in year_list:
    if year  == 'state':
        continue
    path = top_transcn_path+year+'/'
    quarter_list = os.listdir(path)
    for quarter in quarter_list:
        qtr_path = path+quarter
        D = open(qtr_path,'r')
        data =json.load(D)
        for value in  data['data']['states']:
            Name = value['entityName']
            count = value['metric']['count']
            amount=(value['metric']['amount'])
            top_transcn_by_st['Transaction_amount'].append(amount)
            top_transcn_by_st['Transaction_count'].append(count)
            top_transcn_by_st['State'].append(Name)
            top_transcn_by_st['Year'].append(year)
            top_transcn_by_st['Quarter'].append(int(quarter.strip('.json')))
        for value in  data['data']['districts']:
            Name = value['entityName']
            count = value['metric']['count']
            amount=(value['metric']['amount'])
            top_transcn_by_dt['Transaction_amount'].append(amount)
            top_transcn_by_dt['Transaction_count'].append(count)
            top_transcn_by_dt['District'].append(Name)
            top_transcn_by_dt['Year'].append(year)
            top_transcn_by_dt['Quarter'].append(int(quarter.strip('.json')))
        for value in  data['data']['states']:
            Name = value['entityName']
            count = value['metric']['count']
            amount=(value['metric']['amount'])
            top_transcn_by_pcd['Transaction_amount'].append(amount)
            top_transcn_by_pcd['Transaction_count'].append(count)
            top_transcn_by_pcd['PinCode'].append(Name)
            top_transcn_by_pcd['Year'].append(year)
            top_transcn_by_pcd['Quarter'].append(int(quarter.strip('.json')))

top_transcation_st_df = pd.DataFrame(top_transcn_by_st) 
top_transcation_dt_df = pd.DataFrame(top_transcn_by_dt) 
top_transcation_pcd_df = pd.DataFrame(top_transcn_by_pcd)

# %%
top_transcation_pcd_df.head()
# Out:
#           PinCode  Year  Quarter  Transaction_count  Transaction_amount
# 0     maharashtra  2018        1           16387034        2.171161e+10
# 1   uttar pradesh  2018        1           12537805        1.393997e+10
# 2       karnataka  2018        1           12016899        1.921790e+10
# 3     west bengal  2018        1           11710225        1.062598e+10
# 4  andhra pradesh  2018        1            9039585        1.199628e+10

# %%
import json
import pandas as pd
import os
import uuid

top_state_transaction_path = 'D:/Learning/Projects/PhonepePulseDataVisualization/src/phonepeData/data/top/transaction/country/india/state/'

top_st_transaction_pincode ={'State': [], 'Year': [], 'Quarter': [], 'Pincode': [], 'Transaction_count': [],
            'Transaction_amount': []}
top_st_transaction_district ={'State': [], 'Year': [], 'Quarter': [], 'District': [], 'Transaction_count': [],
            'Transaction_amount': []}

state_list = os.listdir(top_state_transaction_path)

for state in state_list:
    state_path = top_state_transaction_path+state+'/'
    year_list = os.listdir(state_path)
    for year in year_list:
        path = state_path+year+'/'
        quarter_list = os.listdir(path)
        for quarter in quarter_list:
            qtr_path = path+quarter
            D = open(qtr_path,'r')
            data =json.load(D)
           
            for value in  data['data']['pincodes']:
                Name = value['entityName']
                count = value['metric']['count']
                amount=(value['metric']['amount'])
                top_st_transaction_pincode['Transaction_amount'].append(amount)
                top_st_transaction_pincode['Transaction_count'].append(count)
                top_st_transaction_pincode['Pincode'].append(Name)
                top_st_transaction_pincode['State'].append(state)
                top_st_transaction_pincode['Year'].append(year)
                top_st_transaction_pincode['Quarter'].append(int(quarter.strip('.json')))
            
            for value in data['data']['districts']:
                Name = value['entityName']
                count = value['metric']['count']
                amount=(value['metric']['amount'])
                top_st_transaction_district['Transaction_amount'].append(amount)
                top_st_transaction_district['Transaction_count'].append(count)
                top_st_transaction_district['District'].append(Name)
                top_st_transaction_district['State'].append(state)
                top_st_transaction_district['Year'].append(year)
                top_st_transaction_district['Quarter'].append(int(quarter.strip('.json')))
                    
                   

    top_st_transcation_pincode_df = pd.DataFrame(top_st_transaction_pincode)
    top_st_transcation_pincode_df["State"] = top_st_transcation_pincode_df[
        "State"
    ].str.title()
    top_st_transcation_pincode_df.fillna(0,inplace=True)
    top_st_transcation_district_df = pd.DataFrame(top_st_transaction_district)
    top_st_transcation_district_df["State"] = top_st_transcation_district_df[
        "State"
    ].str.title()

# %%
top_st_transcation_pincode_df
# Out:
#                           State  Year  Quarter Pincode  Transaction_count  \
# 0     Andaman-&-Nicobar-Islands  2018        1  744101               1622
# 1     Andaman-&-Nicobar-Islands  2018        1  744103               1223
# 2     Andaman-&-Nicobar-Islands  2018        1  744102                969
# 3     Andaman-&-Nicobar-Islands  2018        1  744105                685
# 4     Andaman-&-Nicobar-Islands  2018        1  744104                340
# ...                         ...   ...      ...     ...                ...
# 8562                West-Bengal  2023        4  721301            4133775
# 8563                West-Bengal  2023        4  700001            3983241
# 8564                West-Bengal  2023        4  732125            3950411
# 8565                West-Bengal  2023        4  700039            3742452
# 8566                West-Bengal  2023        4  700014            3652710
#
#       Transaction_amount
# 0           2.769298e+06
# 1           2.238042e+06
# 2           3.519060e+06
# 3           1.298561e+06
# 4           1.039715e+06
# ...                  ...
# 8562        5.718222e+09
# 8563        8.039689e+09
# 8564        6.557345e+09
# 8565        5.608622e+09
# 8566        6.184795e+09
#
# [8567 rows x 6 columns]

# %%
def insert():
    try:
        trans_by_pincode = top_st_transcation_pincode_df
        connection = psql_client()
        cursor = connection.cursor()

        for index, row in trans_by_pincode.iterrows():
            print(row)
            # print(row)
            # Get state_id
            state_name = row["State"]
            cursor.execute(
                f"SELECT id FROM phonepe.state WHERE state_name='{state_name}'"
            )
            state_id = cursor.fetchone()[0]
            cursor.fetchall()
            # Get year_id
            year_value = row["Year"]
            cursor.execute(f"SELECT id FROM phonepe.year WHERE year={year_value}")
            year_id = cursor.fetchone()[0]
            cursor.fetchall()  # Fetch all results to clear the unread result
            # Insert transaction data
            cursor.execute(
                f"""INSERT INTO phonepe.pincode_table_transaction(pin_code_key,
                               pincode, 
                               total_transaction_count,
                               total_transaction_amount,
                               quarter, 
                               state_key, 
                               year_key)
	                           VALUES (
                                '{uuid.uuid4()}',
                                '{row['Pincode']}',
                                 {row['Transaction_count']},
                                 {row['Transaction_amount']},
                                {row['Quarter']}, 
                                {state_id}, 
                                {year_id})"""
            )
            connection.commit()
    except (psycopg2.Error, Exception) as e:
        print("An error occurred:", e)
    finally:
        if connection:
            connection.close()

# %%
insert()
# Out:
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       1
# Pincode                                  744101
# Transaction_count                          1622
# Transaction_amount                  2769297.904
# Name: 0, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       1
# Pincode                                  744103
# Transaction_count                          1223
# Transaction_amount               2238041.871612
# Name: 1, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       1
# Pincode                                  744102
# Transaction_count                           969
# Transaction_amount               3519059.937562
# Name: 2, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       1
# Pincode                                  744105
# Transaction_count                           685
# Transaction_amount                1298560.95155
# Name: 3, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       1
# Pincode                                  744104
# Transaction_count                           340
# Transaction_amount               1039715.311145
# Name: 4, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       1
# Pincode                                  744107
# Transaction_count                           302
# Transaction_amount                556059.530856
# Name: 5, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       1
# Pincode                                  744301
# Transaction_count                           283
# Transaction_amount                445739.163385
# Name: 6, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       1
# Pincode                                  744112
# Transaction_count                           269
# Transaction_amount                333709.567004
# Name: 7, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       1
# Pincode                                  744202
# Transaction_count                           193
# Transaction_amount                238914.016672
# Name: 8, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       1
# Pincode                                  744302
# Transaction_count                           168
# Transaction_amount                547469.650938
# Name: 9, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       2
# Pincode                                  744101
# Transaction_count                          2701
# Transaction_amount               6310089.917085
# Name: 10, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       2
# Pincode                                  744103
# Transaction_count                          1965
# Transaction_amount               4752146.698501
# Name: 11, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       2
# Pincode                                  744102
# Transaction_count                          1525
# Transaction_amount               5810267.574788
# Name: 12, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       2
# Pincode                                  744105
# Transaction_count                           997
# Transaction_amount               2200332.971863
# Name: 13, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       2
# Pincode                                  744301
# Transaction_count                           767
# Transaction_amount                1953749.37872
# Name: 14, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       2
# Pincode                                  744104
# Transaction_count                           659
# Transaction_amount               1650346.190651
# Name: 15, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       2
# Pincode                                  744107
# Transaction_count                           594
# Transaction_amount               1601569.982144
# Name: 16, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       2
# Pincode                                  744112
# Transaction_count                           432
# Transaction_amount                578829.179523
# Name: 17, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       2
# Pincode                                  744202
# Transaction_count                           405
# Transaction_amount                626523.980315
# Name: 18, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       2
# Pincode                                  744302
# Transaction_count                           291
# Transaction_amount               1026590.073586
# Name: 19, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       3
# Pincode                                  744101
# Transaction_count                          3462
# Transaction_amount              10833893.444489
# Name: 20, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       3
# Pincode                                  744103
# Transaction_count                          3182
# Transaction_amount              10184154.358592
# Name: 21, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       3
# Pincode                                  744102
# Transaction_count                          2224
# Transaction_amount              10365275.479701
# Name: 22, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       3
# Pincode                                  744105
# Transaction_count                          1613
# Transaction_amount               5152534.080403
# Name: 23, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       3
# Pincode                                  744104
# Transaction_count                          1029
# Transaction_amount               2588077.686658
# Name: 24, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       3
# Pincode                                  744301
# Transaction_count                           975
# Transaction_amount               4256576.349619
# Name: 25, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       3
# Pincode                                  744112
# Transaction_count                           579
# Transaction_amount               1145815.780171
# Name: 26, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       3
# Pincode                                  744107
# Transaction_count                           547
# Transaction_amount               1492405.302862
# Name: 27, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       3
# Pincode                                  744302
# Transaction_count                           417
# Transaction_amount               1976781.919949
# Name: 28, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       3
# Pincode                                  744202
# Transaction_count                           341
# Transaction_amount               2099404.078986
# Name: 29, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       4
# Pincode                                  744101
# Transaction_count                          4674
# Transaction_amount              16392855.280625
# Name: 30, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       4
# Pincode                                  744103
# Transaction_count                          4576
# Transaction_amount              17022520.257625
# Name: 31, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       4
# Pincode                                  744102
# Transaction_count                          3306
# Transaction_amount              17019977.183054
# Name: 32, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       4
# Pincode                                  744105
# Transaction_count                          2513
# Transaction_amount               9935282.832151
# Name: 33, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       4
# Pincode                                  744104
# Transaction_count                          1432
# Transaction_amount               6091757.917089
# Name: 34, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       4
# Pincode                                  744211
# Transaction_count                          1225
# Transaction_amount               3451359.606027
# Name: 35, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       4
# Pincode                                  744301
# Transaction_count                           928
# Transaction_amount               4606293.657526
# Name: 36, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       4
# Pincode                                  744112
# Transaction_count                           759
# Transaction_amount               2208675.043571
# Name: 37, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       4
# Pincode                                  744107
# Transaction_count                           747
# Transaction_amount               1825659.512898
# Name: 38, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2018
# Quarter                                       4
# Pincode                                  744202
# Transaction_count                           702
# Transaction_amount               3797054.167763
# Name: 39, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       1
# Pincode                                  744103
# Transaction_count                          5742
# Transaction_amount              19401964.779658
# Name: 40, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       1
# Pincode                                  744101
# Transaction_count                          5156
# Transaction_amount              15501306.227196
# Name: 41, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       1
# Pincode                                  744102
# Transaction_count                          3925
# Transaction_amount              16683547.094796
# Name: 42, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       1
# Pincode                                  744105
# Transaction_count                          3553
# Transaction_amount              11588669.480329
# Name: 43, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       1
# Pincode                                  744104
# Transaction_count                          2833
# Transaction_amount               9141657.219605
# Name: 44, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       1
# Pincode                                  744211
# Transaction_count                          1511
# Transaction_amount               5794838.401832
# Name: 45, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       1
# Pincode                                  744202
# Transaction_count                          1112
# Transaction_amount               3613381.294736
# Name: 46, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       1
# Pincode                                  744107
# Transaction_count                          1029
# Transaction_amount               3592930.297578
# Name: 47, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       1
# Pincode                                  744301
# Transaction_count                           920
# Transaction_amount               4652963.411148
# Name: 48, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       1
# Pincode                                  744112
# Transaction_count                           802
# Transaction_amount               1893718.653782
# Name: 49, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       2
# Pincode                                  744104
# Transaction_count                          6142
# Transaction_amount              15625676.560883
# Name: 50, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       2
# Pincode                                  744103
# Transaction_count                          5847
# Transaction_amount              23751450.067207
# Name: 51, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       2
# Pincode                                  744101
# Transaction_count                          4863
# Transaction_amount              19061125.411219
# Name: 52, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       2
# Pincode                                  744102
# Transaction_count                          4120
# Transaction_amount              18948733.987098
# Name: 53, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       2
# Pincode                                  744105
# Transaction_count                          3500
# Transaction_amount              13418692.199163
# Name: 54, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       2
# Pincode                                  744202
# Transaction_count                          1153
# Transaction_amount               3619993.391079
# Name: 55, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       2
# Pincode                                  744107
# Transaction_count                          1124
# Transaction_amount               2967445.390203
# Name: 56, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       2
# Pincode                                  744211
# Transaction_count                          1047
# Transaction_amount               3168331.991735
# Name: 57, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       2
# Pincode                                  744301
# Transaction_count                          1007
# Transaction_amount                4849284.51926
# Name: 58, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       2
# Pincode                                  744112
# Transaction_count                           763
# Transaction_amount               2928099.608406
# Name: 59, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       3
# Pincode                                  744103
# Transaction_count                          5680
# Transaction_amount              19906337.014256
# Name: 60, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       3
# Pincode                                  744101
# Transaction_count                          5606
# Transaction_amount              18745152.093516
# Name: 61, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       3
# Pincode                                  744104
# Transaction_count                          4786
# Transaction_amount              15754793.354826
# Name: 62, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       3
# Pincode                                  744102
# Transaction_count                          3643
# Transaction_amount              14572605.602745
# Name: 63, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       3
# Pincode                                  744105
# Transaction_count                          3512
# Transaction_amount              11767223.996888
# Name: 64, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       3
# Pincode                                  744202
# Transaction_count                          1417
# Transaction_amount               3875602.098203
# Name: 65, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       3
# Pincode                                  744301
# Transaction_count                          1402
# Transaction_amount                6195496.62173
# Name: 66, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       3
# Pincode                                  744211
# Transaction_count                          1118
# Transaction_amount               2983697.449378
# Name: 67, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       3
# Pincode                                  744107
# Transaction_count                           914
# Transaction_amount               1988299.759711
# Name: 68, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       3
# Pincode                                  744112
# Transaction_count                           833
# Transaction_amount               2198831.691941
# Name: 69, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       4
# Pincode                                  744104
# Transaction_count                          6633
# Transaction_amount              20626642.701509
# Name: 70, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       4
# Pincode                                  744101
# Transaction_count                          5282
# Transaction_amount              23247752.473849
# Name: 71, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       4
# Pincode                                  744103
# Transaction_count                          4840
# Transaction_amount              19792507.955761
# Name: 72, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       4
# Pincode                                  744105
# Transaction_count                          3528
# Transaction_amount               15302141.17488
# Name: 73, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       4
# Pincode                                  744102
# Transaction_count                          3237
# Transaction_amount              15350444.973208
# Name: 74, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       4
# Pincode                                  744202
# Transaction_count                          1783
# Transaction_amount               5800016.556113
# Name: 75, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       4
# Pincode                                  744211
# Transaction_count                          1596
# Transaction_amount               7908264.721919
# Name: 76, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       4
# Pincode                                  744301
# Transaction_count                          1549
# Transaction_amount               7056478.928839
# Name: 77, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       4
# Pincode                                  744201
# Transaction_count                           886
# Transaction_amount                946768.063648
# Name: 78, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2019
# Quarter                                       4
# Pincode                                  744107
# Transaction_count                           777
# Transaction_amount                 3030368.9119
# Name: 79, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       1
# Pincode                                  744101
# Transaction_count                         11793
# Transaction_amount              58229349.024152
# Name: 80, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       1
# Pincode                                  744103
# Transaction_count                          5870
# Transaction_amount              22009443.073054
# Name: 81, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       1
# Pincode                                  744105
# Transaction_count                          4635
# Transaction_amount              16774043.311988
# Name: 82, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       1
# Pincode                                  744102
# Transaction_count                          3820
# Transaction_amount              14517706.122697
# Name: 83, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       1
# Pincode                                  744211
# Transaction_count                          1837
# Transaction_amount               8425387.790042
# Name: 84, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       1
# Pincode                                  744301
# Transaction_count                          1819
# Transaction_amount                6901162.10752
# Name: 85, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       1
# Pincode                                  744202
# Transaction_count                          1794
# Transaction_amount               5037742.395579
# Name: 86, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       1
# Pincode                                  744104
# Transaction_count                          1302
# Transaction_amount               5293130.290634
# Name: 87, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       1
# Pincode                                  744201
# Transaction_count                          1157
# Transaction_amount               1242638.821253
# Name: 88, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       1
# Pincode                                  744107
# Transaction_count                          1043
# Transaction_amount               2990354.444855
# Name: 89, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       2
# Pincode                                  744101
# Transaction_count                         11868
# Transaction_amount               48293323.21852
# Name: 90, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       2
# Pincode                                  744103
# Transaction_count                         10035
# Transaction_amount              26197535.989452
# Name: 91, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       2
# Pincode                                  744105
# Transaction_count                          9341
# Transaction_amount              23203019.858981
# Name: 92, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       2
# Pincode                                  744102
# Transaction_count                          6012
# Transaction_amount              17786750.907516
# Name: 93, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       2
# Pincode                                  744202
# Transaction_count                          3722
# Transaction_amount               8924121.010763
# Name: 94, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       2
# Pincode                                  744107
# Transaction_count                          2555
# Transaction_amount                3980470.68537
# Name: 95, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       2
# Pincode                                  744301
# Transaction_count                          2275
# Transaction_amount               9055232.527756
# Name: 96, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       2
# Pincode                                  744211
# Transaction_count                          2045
# Transaction_amount               3319717.632879
# Name: 97, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       2
# Pincode                                  744205
# Transaction_count                          1847
# Transaction_amount                4459064.90732
# Name: 98, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       2
# Pincode                                  744104
# Transaction_count                          1840
# Transaction_amount               3334591.822305
# Name: 99, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       3
# Pincode                                  744101
# Transaction_count                         24386
# Transaction_amount             100439119.668608
# Name: 100, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       3
# Pincode                                  744103
# Transaction_count                         21272
# Transaction_amount              60332278.693968
# Name: 101, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       3
# Pincode                                  744105
# Transaction_count                         17166
# Transaction_amount              44061506.562736
# Name: 102, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       3
# Pincode                                  744102
# Transaction_count                         13934
# Transaction_amount              43077189.842844
# Name: 103, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       3
# Pincode                                  744202
# Transaction_count                          5779
# Transaction_amount              11975748.707877
# Name: 104, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       3
# Pincode                                  744107
# Transaction_count                          4753
# Transaction_amount               7628018.669465
# Name: 105, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       3
# Pincode                                  744104
# Transaction_count                          3468
# Transaction_amount               7353834.513209
# Name: 106, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       3
# Pincode                                  744112
# Transaction_count                          3422
# Transaction_amount               6067986.696112
# Name: 107, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       3
# Pincode                                  744301
# Transaction_count                          3071
# Transaction_amount               13352610.53156
# Name: 108, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       3
# Pincode                                  744205
# Transaction_count                          2991
# Transaction_amount               7535645.788594
# Name: 109, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       4
# Pincode                                  744103
# Transaction_count                         46884
# Transaction_amount             138264791.548921
# Name: 110, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       4
# Pincode                                  744101
# Transaction_count                         40392
# Transaction_amount             136401368.021666
# Name: 111, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       4
# Pincode                                  744105
# Transaction_count                         34410
# Transaction_amount              87838226.936334
# Name: 112, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       4
# Pincode                                  744102
# Transaction_count                         26694
# Transaction_amount              76348598.322384
# Name: 113, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       4
# Pincode                                  744202
# Transaction_count                         10949
# Transaction_amount               25543799.07476
# Name: 114, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       4
# Pincode                                  744107
# Transaction_count                          9743
# Transaction_amount              18083250.190554
# Name: 115, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       4
# Pincode                                  744104
# Transaction_count                          7654
# Transaction_amount              19126095.533285
# Name: 116, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       4
# Pincode                                  744112
# Transaction_count                          7016
# Transaction_amount              15890275.050448
# Name: 117, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       4
# Pincode                                  744205
# Transaction_count                          5118
# Transaction_amount              12002695.281042
# Name: 118, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2020
# Quarter                                       4
# Pincode                                  744201
# Transaction_count                          5011
# Transaction_amount               6777275.536669
# Name: 119, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       1
# Pincode                                  744101
# Transaction_count                         55726
# Transaction_amount             190830957.060618
# Name: 120, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       1
# Pincode                                  744103
# Transaction_count                         47328
# Transaction_amount             158404100.785499
# Name: 121, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       1
# Pincode                                  744105
# Transaction_count                         35467
# Transaction_amount             111571687.431952
# Name: 122, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       1
# Pincode                                  744102
# Transaction_count                         23957
# Transaction_amount              80750048.823896
# Name: 123, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       1
# Pincode                                  744211
# Transaction_count                         10648
# Transaction_amount              34956327.941054
# Name: 124, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       1
# Pincode                                  744202
# Transaction_count                         10597
# Transaction_amount              28127629.877962
# Name: 125, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       1
# Pincode                                  744107
# Transaction_count                          8848
# Transaction_amount              19627951.469969
# Name: 126, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       1
# Pincode                                  744104
# Transaction_count                          8799
# Transaction_amount              27854306.519496
# Name: 127, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       1
# Pincode                                  744112
# Transaction_count                          7113
# Transaction_amount              21084790.052801
# Name: 128, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       1
# Pincode                                  744301
# Transaction_count                          5630
# Transaction_amount              22671937.313148
# Name: 129, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       2
# Pincode                                  744101
# Transaction_count                         73334
# Transaction_amount             227585492.741459
# Name: 130, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       2
# Pincode                                  744103
# Transaction_count                         66321
# Transaction_amount             174752815.168852
# Name: 131, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       2
# Pincode                                  744105
# Transaction_count                         52645
# Transaction_amount             134835744.220492
# Name: 132, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       2
# Pincode                                  744102
# Transaction_count                         34289
# Transaction_amount             100890426.762341
# Name: 133, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       2
# Pincode                                  744202
# Transaction_count                         16476
# Transaction_amount              40647907.969608
# Name: 134, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       2
# Pincode                                  744107
# Transaction_count                         14524
# Transaction_amount              24690581.539095
# Name: 135, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       2
# Pincode                                  744104
# Transaction_count                         11278
# Transaction_amount              28333852.061593
# Name: 136, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       2
# Pincode                                  744211
# Transaction_count                         10182
# Transaction_amount              20377949.346095
# Name: 137, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       2
# Pincode                                  744112
# Transaction_count                          9635
# Transaction_amount                21637658.1672
# Name: 138, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       2
# Pincode                                  744301
# Transaction_count                          8463
# Transaction_amount              27666837.396883
# Name: 139, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       3
# Pincode                                  744101
# Transaction_count                        116324
# Transaction_amount             388328168.763969
# Name: 140, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       3
# Pincode                                  744103
# Transaction_count                         84790
# Transaction_amount             246433385.809901
# Name: 141, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       3
# Pincode                                  744105
# Transaction_count                         67257
# Transaction_amount             185238368.476708
# Name: 142, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       3
# Pincode                                  744102
# Transaction_count                         43850
# Transaction_amount             131239564.169097
# Name: 143, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       3
# Pincode                                  744202
# Transaction_count                         19088
# Transaction_amount              48475163.574293
# Name: 144, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       3
# Pincode                                  744107
# Transaction_count                         16203
# Transaction_amount               37962312.09641
# Name: 145, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       3
# Pincode                                  744104
# Transaction_count                         14657
# Transaction_amount              35301326.114472
# Name: 146, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       3
# Pincode                                  744112
# Transaction_count                         11565
# Transaction_amount               28491553.61094
# Name: 147, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       3
# Pincode                                  744301
# Transaction_count                         11553
# Transaction_amount              43464511.051198
# Name: 148, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       3
# Pincode                                  744211
# Transaction_count                          9655
# Transaction_amount              19497765.257141
# Name: 149, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       4
# Pincode                                  744101
# Transaction_count                        165719
# Transaction_amount              533026207.97318
# Name: 150, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       4
# Pincode                                  744103
# Transaction_count                        121613
# Transaction_amount             372243734.279857
# Name: 151, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       4
# Pincode                                  744105
# Transaction_count                         95028
# Transaction_amount             281223411.743506
# Name: 152, dtype: object
# State                 Andaman-&-Nicobar-Islands
# Year                                       2021
# Quarter                                       4
# Pincode                                  744102
# ...
# Transaction_count               2311229
# Transaction_amount    6284886223.830292
# Name: 8502, dtype: object
# State                       West-Bengal
# Year                               2022
# Quarter                               2
# Pincode                          700091
# Transaction_count               2018277
# Transaction_amount    2013232488.953846
# Name: 8503, dtype: object
# State                       West-Bengal
# Year                               2022
# Quarter                               2
# Pincode                          700135
# Transaction_count               1992974
# Transaction_amount    3111680063.663621
# Name: 8504, dtype: object
# State                       West-Bengal
# Year                               2022
# Quarter                               2
# Pincode                          711101
# Transaction_count               1491729
# Transaction_amount    3752715059.844947
# Name: 8505, dtype: object
# State                       West-Bengal
# Year                               2022
# Quarter                               2
# Pincode                          721301
# Transaction_count               1330885
# Transaction_amount    2655521582.949104
# Name: 8506, dtype: object
# State                         West-Bengal
# Year                                 2022
# Quarter                                 3
# Pincode                            700039
# Transaction_count                82900479
# Transaction_amount    153815755896.188141
# Name: 8507, dtype: object
# State                        West-Bengal
# Year                                2022
# Quarter                                3
# Pincode                           713104
# Transaction_count               11032984
# Transaction_amount    21047126550.056625
# Name: 8508, dtype: object
# State                        West-Bengal
# Year                                2022
# Quarter                                3
# Pincode                           700009
# Transaction_count                9983647
# Transaction_amount    19215932067.617313
# Name: 8509, dtype: object
# State                       West-Bengal
# Year                               2022
# Quarter                               3
# Pincode                          734006
# Transaction_count               3507614
# Transaction_amount    7153982146.945021
# Name: 8510, dtype: object
# State                       West-Bengal
# Year                               2022
# Quarter                               3
# Pincode                          713208
# Transaction_count               3459655
# Transaction_amount    5974201946.726851
# Name: 8511, dtype: object
# State                       West-Bengal
# Year                               2022
# Quarter                               3
# Pincode                          711102
# Transaction_count               3116021
# Transaction_amount    5773800446.207191
# Name: 8512, dtype: object
# State                       West-Bengal
# Year                               2022
# Quarter                               3
# Pincode                          732101
# Transaction_count               3015305
# Transaction_amount    6230805244.371487
# Name: 8513, dtype: object
# State                      West-Bengal
# Year                              2022
# Quarter                              3
# Pincode                         700156
# Transaction_count              2907953
# Transaction_amount    3066173661.65435
# Name: 8514, dtype: object
# State                       West-Bengal
# Year                               2022
# Quarter                               3
# Pincode                          736121
# Transaction_count               2404119
# Transaction_amount    4692644795.370488
# Name: 8515, dtype: object
# State                       West-Bengal
# Year                               2022
# Quarter                               3
# Pincode                          700091
# Transaction_count               2193547
# Transaction_amount    2185165475.216927
# Name: 8516, dtype: object
# State                         West-Bengal
# Year                                 2022
# Quarter                                 4
# Pincode                            700039
# Transaction_count               119193886
# Transaction_amount    219834107643.853546
# Name: 8517, dtype: object
# State                        West-Bengal
# Year                                2022
# Quarter                                4
# Pincode                           713104
# Transaction_count               14905151
# Transaction_amount    27967161621.247257
# Name: 8518, dtype: object
# State                       West-Bengal
# Year                               2022
# Quarter                               4
# Pincode                          713208
# Transaction_count               3670500
# Transaction_amount    6276614139.355786
# Name: 8519, dtype: object
# State                       West-Bengal
# Year                               2022
# Quarter                               4
# Pincode                          700156
# Transaction_count               3321558
# Transaction_amount    3249717376.478173
# Name: 8520, dtype: object
# State                       West-Bengal
# Year                               2022
# Quarter                               4
# Pincode                          734006
# Transaction_count               2946630
# Transaction_amount    6118057954.747467
# Name: 8521, dtype: object
# State                       West-Bengal
# Year                               2022
# Quarter                               4
# Pincode                          722101
# Transaction_count               2900058
# Transaction_amount    5748321357.624565
# Name: 8522, dtype: object
# State                      West-Bengal
# Year                              2022
# Quarter                              4
# Pincode                         700135
# Transaction_count              2471048
# Transaction_amount    3527456983.66468
# Name: 8523, dtype: object
# State                       West-Bengal
# Year                               2022
# Quarter                               4
# Pincode                          732101
# Transaction_count               2407008
# Transaction_amount    5052109230.097512
# Name: 8524, dtype: object
# State                       West-Bengal
# Year                               2022
# Quarter                               4
# Pincode                          700091
# Transaction_count               2348447
# Transaction_amount    2176639604.949575
# Name: 8525, dtype: object
# State                       West-Bengal
# Year                               2022
# Quarter                               4
# Pincode                          711101
# Transaction_count               1765314
# Transaction_amount    4048328948.279814
# Name: 8526, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          1
# Pincode                     700156
# Transaction_count          5958877
# Transaction_amount    5609483195.0
# Name: 8527, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          1
# Pincode                     700135
# Transaction_count          4509337
# Transaction_amount    6287886387.0
# Name: 8528, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          1
# Pincode                     700091
# Transaction_count          4304650
# Transaction_amount    3758758438.0
# Name: 8529, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          1
# Pincode                     711101
# Transaction_count          3199541
# Transaction_amount    7319941734.0
# Name: 8530, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          1
# Pincode                     700006
# Transaction_count          2709188
# Transaction_amount    5691967086.0
# Name: 8531, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          1
# Pincode                     700001
# Transaction_count          2556546
# Transaction_amount    6010476113.0
# Name: 8532, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          1
# Pincode                     700039
# Transaction_count          2480336
# Transaction_amount    4166093050.0
# Name: 8533, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          1
# Pincode                     700014
# Transaction_count          2436910
# Transaction_amount    4697968182.0
# Name: 8534, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          1
# Pincode                     700015
# Transaction_count          2411466
# Transaction_amount    3984157258.0
# Name: 8535, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          1
# Pincode                     721301
# Transaction_count          2394763
# Transaction_amount    3890202029.0
# Name: 8536, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          2
# Pincode                     700156
# Transaction_count          6927595
# Transaction_amount    6467350121.0
# Name: 8537, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          2
# Pincode                     700135
# Transaction_count          5416429
# Transaction_amount    7132792877.0
# Name: 8538, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          2
# Pincode                     700091
# Transaction_count          4970887
# Transaction_amount    4221400843.0
# Name: 8539, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          2
# Pincode                     711101
# Transaction_count          3734933
# Transaction_amount    8035948465.0
# Name: 8540, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          2
# Pincode                     700006
# Transaction_count          3158355
# Transaction_amount    6225337500.0
# Name: 8541, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          2
# Pincode                     700001
# Transaction_count          2918444
# Transaction_amount    6259876962.0
# Name: 8542, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          2
# Pincode                     721301
# Transaction_count          2910870
# Transaction_amount    4458107291.0
# Name: 8543, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          2
# Pincode                     700039
# Transaction_count          2886562
# Transaction_amount    4662886799.0
# Name: 8544, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          2
# Pincode                     700015
# Transaction_count          2774383
# Transaction_amount    4372974747.0
# Name: 8545, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          2
# Pincode                     700014
# Transaction_count          2757479
# Transaction_amount    5108638497.0
# Name: 8546, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          3
# Pincode                     700156
# Transaction_count          8289388
# Transaction_amount    7339618058.0
# Name: 8547, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          3
# Pincode                     700135
# Transaction_count          6459974
# Transaction_amount    7717822253.0
# Name: 8548, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          3
# Pincode                     700091
# Transaction_count          5867493
# Transaction_amount    4821546529.0
# Name: 8549, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          3
# Pincode                     711101
# Transaction_count          4369730
# Transaction_amount    8869029935.0
# Name: 8550, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          3
# Pincode                     700006
# Transaction_count          3709713
# Transaction_amount    6909273704.0
# Name: 8551, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          3
# Pincode                     700001
# Transaction_count          3536928
# Transaction_amount    7193521561.0
# Name: 8552, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          3
# Pincode                     721301
# Transaction_count          3464729
# Transaction_amount    4871566033.0
# Name: 8553, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          3
# Pincode                     700039
# Transaction_count          3405551
# Transaction_amount    5095824624.0
# Name: 8554, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          3
# Pincode                     732125
# Transaction_count          3347165
# Transaction_amount    5353831211.0
# Name: 8555, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          3
# Pincode                     700015
# Transaction_count          3304464
# Transaction_amount    5003673712.0
# Name: 8556, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          4
# Pincode                     700156
# Transaction_count          8786298
# Transaction_amount    7815868697.0
# Name: 8557, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          4
# Pincode                     700135
# Transaction_count          7170174
# Transaction_amount    8880357042.0
# Name: 8558, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          4
# Pincode                     700091
# Transaction_count          5884190
# Transaction_amount    4935076443.0
# Name: 8559, dtype: object
# State                   West-Bengal
# Year                           2023
# Quarter                           4
# Pincode                      711101
# Transaction_count           5092876
# Transaction_amount    10012668632.0
# Name: 8560, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          4
# Pincode                     700006
# Transaction_count          4216394
# Transaction_amount    7851936248.0
# Name: 8561, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          4
# Pincode                     721301
# Transaction_count          4133775
# Transaction_amount    5718222071.0
# Name: 8562, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          4
# Pincode                     700001
# Transaction_count          3983241
# Transaction_amount    8039688940.0
# Name: 8563, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          4
# Pincode                     732125
# Transaction_count          3950411
# Transaction_amount    6557344712.0
# Name: 8564, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          4
# Pincode                     700039
# Transaction_count          3742452
# Transaction_amount    5608622243.0
# Name: 8565, dtype: object
# State                  West-Bengal
# Year                          2023
# Quarter                          4
# Pincode                     700014
# Transaction_count          3652710
# Transaction_amount    6184795262.0
# Name: 8566, dtype: object

# %%
import json
import pandas as pd
import os
top_user_path='D:/Learning/Projects/PhonepePulseDataVisualization/src/phonepeData/data/top/user/country/india/'

top_st_by_user ={'Year': [], 'Quarter': [], 'State': [], 'Count': []}
top_dt_by_user ={'Year': [], 'Quarter': [], 'District': [], 'Count': []}
top_pcd_by_user ={'Year': [], 'Quarter': [], 'PinCode': [], 'Count': []}

year_list = os.listdir(top_user_path)
for year in year_list:
    if year == 'state':
        continue
    path = top_user_path+year+'/'
    quarter_list = os.listdir(path)
    for quarter in quarter_list:
        qtr_path = path+quarter
        D = open(qtr_path,'r')
        data =json.load(D)
        for value in data['data']['states']:
            Name = value['name']
            count = value['registeredUsers']
            top_st_by_user['State'].append(Name)
            top_st_by_user['Count'].append(count)
            top_st_by_user['Year'].append(year)
            top_st_by_user['Quarter'].append(int(quarter.strip('.json')))
        for value in data['data']['districts']:
            Name = value['name']
            count = value['registeredUsers']
            top_dt_by_user['District'].append(Name)
            top_dt_by_user['Count'].append(count)
            top_dt_by_user['Year'].append(year)
            top_dt_by_user['Quarter'].append(int(quarter.strip('.json')))
        for value in data['data']['pincodes']:
            Name = value['name']
            count = value['registeredUsers']
            top_pcd_by_user['PinCode'].append(Name)
            top_pcd_by_user['Count'].append(count)
            top_pcd_by_user['Year'].append(year)
            top_pcd_by_user['Quarter'].append(int(quarter.strip('.json')))            
        
   

top_st_user_df = pd.DataFrame(top_st_by_user)
top_dt_user_df = pd.DataFrame(top_dt_by_user)
top_pcd_user_df = pd.DataFrame(top_pcd_by_user)

# %%
top_pcd_user_df

# %%
import json
import pandas as pd
import os
top_state_user_path = 'D:/Learning/Projects/PhonepePulseDataVisualization/src/phonepeData/data/top/user/country/india/state/'

top_usr_by_st_pincode ={'State': [], 'Year': [], 'Quarter': [], 'Pincode': [], 'Count': []}
top_usr_by_st_district ={'State': [], 'Year': [], 'Quarter': [], 'District': [], 'Count': []}

state_list = os.listdir(top_state_user_path)

for state in state_list:
    state_path = top_state_user_path+state+'/'
    year_list = os.listdir(state_path)
    for year in year_list:
        path = state_path+year+'/'
        quarter_list = os.listdir(path)
        for quarter in quarter_list:
            qtr_path = path+quarter
            D = open(qtr_path,'r')
            data =json.load(D)
           
            for value in  data['data']['pincodes']:
                Name = value['name']
                count = value['registeredUsers']
                top_usr_by_st_pincode['Count'].append(count)
                top_usr_by_st_pincode['Pincode'].append(Name)
                top_usr_by_st_pincode['State'].append(state)
                top_usr_by_st_pincode['Year'].append(year)
                top_usr_by_st_pincode['Quarter'].append(int(quarter.strip('.json')))
            
            for value in data['data']['districts']:
                Name = value['name']
                count = value['registeredUsers']
                top_usr_by_st_district['Count'].append(count)
                top_usr_by_st_district['District'].append(Name)
                top_usr_by_st_district['State'].append(state)
                top_usr_by_st_district['Year'].append(year)
                top_usr_by_st_district['Quarter'].append(int(quarter.strip('.json')))
                    
                   

top_st_usr_pincode_df = pd.DataFrame(top_usr_by_st_pincode)    
top_st_usr_pincode_df['State'] = top_st_usr_pincode_df['State'].str.title()
top_st_usr_district_df = pd.DataFrame(top_usr_by_st_district)    
top_st_usr_district_df['State'] = top_st_usr_district_df['State'].str.title()

# %%
top_st_usr_pincode_df.head()
# Out:
#                        State  Year  Quarter Pincode  Count
# 0  Andaman-&-Nicobar-Islands  2018        1  744103   1608
# 1  Andaman-&-Nicobar-Islands  2018        1  744101   1108
# 2  Andaman-&-Nicobar-Islands  2018        1  744105   1075
# 3  Andaman-&-Nicobar-Islands  2018        1  744102   1006
# 4  Andaman-&-Nicobar-Islands  2018        1  744104    272

# %%
import pandas as pd
import plotly.express as px

df = top_st_usr_pincode_df

fig = px.choropleth(
    df,
    geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
    featureidkey='properties.ST_NM',
    locations='State',
    color='Count',
    color_continuous_scale='Reds'
)

fig.update_geos(fitbounds="locations", visible=False)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 17
#       6 fig = px.choropleth(
#       7     df,
#       8     geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
#    (...)
#      12     color_continuous_scale='Reds'
#      13 )
#      15 fig.update_geos(fitbounds="locations", visible=False)
# ---> 17 fig.show()
#
# File d:\Learning\Projects\PhonepePulseDataVisualization\.venv\Lib\site-packages\plotly\basedatatypes.py:3410, in BaseFigure.show(self, *args, **kwargs)
#    3377 """
#    3378 Show a figure using either the default renderer(s) or the renderer(s)
#    3379 specified by the renderer argument
#    (...)
#    3406 None
#    3407 """
#    3408 import plotly.io as pio
# -> 3410 return pio.show(self, *args, **kwargs)
#
# File d:\Learning\Projects\PhonepePulseDataVisualization\.venv\Lib\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
#     391         )
#     393     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 394         raise ValueError(
#     395             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     396         )
#     398     ipython_display.display(bundle, raw=True)
#     400 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %%
import os
import json
import pandas as pd
aggreated_user_state_path='D:/Learning/Projects/PhonepePulseDataVisualization/src/phonepeData/data/aggregated/user/country/india/state/'

state_user ={'State': [], 'Year': [], 'Quarter': [], 'Brands': [], 'Count': [],
            'Percentage': [],'Users_count':[],'App_opening':[]}
state_list = os.listdir(aggreated_user_state_path)
for state in state_list:  
    year_path = aggreated_user_state_path+state+'/'
    year_list = os.listdir(year_path)
    for year in year_list:
        path = year_path+year+'/'
        quarter_list = os.listdir(path)
        for quarter in quarter_list:
            qtr_path = path+quarter
            D = open(qtr_path,'r')
            data =json.load(D)
            user_count = data['data']['aggregated']['registeredUsers']
            app_open = data['data']['aggregated']['appOpens']
            try:  
                for value in  data['data']['usersByDevice']:
                    Brand = value['brand']
                    count = value['count']
                    percent = value['percentage']
                    state_user['Brands'].append(Brand)
                    state_user['Count'].append(count)
                    state_user['Percentage'].append(percent)
                    state_user['Year'].append(year)
                    state_user['State'].append(state)
                    state_user['Quarter'].append(int(quarter.strip('.json')))
                    state_user['Users_count'].append(user_count)
                    state_user['App_opening'].append(app_open)
            except:
                pass        
st_user_df = pd.DataFrame(state_user)

# %%
st_user_df
# Out:
#                           State  Year  Quarter   Brands    Count  Percentage  \
# 0     andaman-&-nicobar-islands  2018        1   Xiaomi     1665    0.247033
# 1     andaman-&-nicobar-islands  2018        1  Samsung     1445    0.214392
# 2     andaman-&-nicobar-islands  2018        1     Vivo      982    0.145697
# 3     andaman-&-nicobar-islands  2018        1     Oppo      501    0.074332
# 4     andaman-&-nicobar-islands  2018        1  OnePlus      332    0.049258
# ...                         ...   ...      ...      ...      ...         ...
# 6727                west-bengal  2022        1   Lenovo   330017    0.015056
# 6728                west-bengal  2022        1  Infinix   284678    0.012987
# 6729                west-bengal  2022        1     Asus   280347    0.012790
# 6730                west-bengal  2022        1    Apple   277752    0.012671
# 6731                west-bengal  2022        1   Others  2196334    0.100199
#
#       Users_count  App_opening
# 0            6740            0
# 1            6740            0
# 2            6740            0
# 3            6740            0
# 4            6740            0
# ...           ...          ...
# 6727     21919787    236131065
# 6728     21919787    236131065
# 6729     21919787    236131065
# 6730     21919787    236131065
# 6731     21919787    236131065
#
# [6732 rows x 8 columns]

# %%
import json
import pandas as pd
import os

map_st_user_path = "D:/Learning/Projects/PhonepePulseDataVisualization/src/phonepeData/data/map/user/hover/country/india/state/"

mp_st_user = {
    "Year": [],
    "Quarter": [],
    "State": [],
    "District": [],
    "Count": [],
    "App_Opening": [],
}
mp_state_list = os.listdir(map_st_user_path)
for state in mp_state_list:
    year_path = map_st_user_path + state + "/"
    year_list = os.listdir(year_path)
    for year in year_list:
        path = year_path + year + "/"
        quarter_list = os.listdir(path)
        for quarter in quarter_list:
            qtr_path = path + quarter
            D = open(qtr_path, "r")
            data = json.load(D)
            # try:
            # Extract state names and data
            districts = list(data["data"]["hoverData"].keys())
            for value in districts:
                district = value
                count = data["data"]["hoverData"][district]["registeredUsers"]
                app_opening = data["data"]["hoverData"][district]["appOpens"]
                mp_st_user["State"].append(state)
                mp_st_user["Count"].append(count)
                mp_st_user["App_Opening"].append(app_opening)
                mp_st_user["Year"].append(year)
                mp_st_user["Quarter"].append(int(quarter.strip(".json")))
                mp_st_user["District"].append(district)
            # except Exception as e:
            # print(e)
            # pass
    map_st_user_df = pd.DataFrame(mp_st_user)
    map_st_user_df["State"] = map_st_user_df["State"].str.title()

# %%
map_st_user_df
# Out:
#        Year  Quarter                      State  \
# 0      2018        1  Andaman-&-Nicobar-Islands
# 1      2018        1  Andaman-&-Nicobar-Islands
# 2      2018        1  Andaman-&-Nicobar-Islands
# 3      2018        2  Andaman-&-Nicobar-Islands
# 4      2018        2  Andaman-&-Nicobar-Islands
# ...     ...      ...                        ...
# 17563  2023        4                West-Bengal
# 17564  2023        4                West-Bengal
# 17565  2023        4                West-Bengal
# 17566  2023        4                West-Bengal
# 17567  2023        4                West-Bengal
#
#                                 District    Count  App_Opening
# 0      north and middle andaman district      632            0
# 1                 south andaman district     5846            0
# 2                      nicobars district      262            0
# 3      north and middle andaman district      911            0
# 4                 south andaman district     8143            0
# ...                                  ...      ...          ...
# 17563                     nadia district  1603527     67224546
# 17564                   birbhum district  1013025     52281841
# 17565           purba medinipur district  1589203     69991821
# 17566                    maldah district  1134600     88292475
# 17567                 darjiling district   660231     39079247
#
# [17568 rows x 6 columns]
